# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 590

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Save config information.
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "Imperial"

# Build partial query URL
query_url = f"{url}appid={weather_api_key}&units={units}&q="


# Get city information in JSON format


city2 = []
lat = []
long = []
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []

# Report the names
for city in cities:
    response = requests.get(query_url + city).json()
    print(city)
    print(response)
    if response['cod'] != '404': 
        city2.append (city)
        lat.append(response['coord']['lat'])
        long.append(response['coord']['lon'])
        max_temp.append(response['main']['temp_max'])
        humidity.append(response['main']['humidity'])
        cloudiness.append(response['clouds']['all'])
        wind_speed.append(response['wind']['speed'])
        country.append(response['sys']['country'])
        date.append(response['dt'])
# Out:
# bluff
# {'coord': {'lon': 168.3333, 'lat': -46.6}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 57.16, 'feels_like': 55.74, 'temp_min': 57.16, 'temp_max': 57.16, 'pressure': 1020, 'humidity': 67, 'sea_level': 1020, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 0.98, 'deg': 197}, 'clouds': {'all': 100}, 'dt': 1612049195, 'sys': {'country': 'NZ', 'sunrise': 1612028215, 'sunset': 1612081383}, 'timezone': 46800, 'id': 2206939, 'name': 'Bluff', 'cod': 200}
# illoqqortoormiut
# {'cod': '404', 'message': 'city not found'}
# marechal deodoro
# {'coord': {'lon': -35.895, 'lat': -9.7103}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 84.85, 'temp_min': 77, 'temp_max': 77, 'pressure': 1014, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 80}, 'clouds': {'all': 40}, 'dt': 1612049196, 'sys': {'type': 1, 'id': 8413, 'country': 'BR', 'sunrise': 1611994852, 'sunset': 1612039968}, 'timezone': -10800, 'id': 3395395, 'name': 'Marechal Deodoro', 'cod': 200}
# bengkulu
# {'coord': {'lon': 102.2655, 'lat': -3.8004}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.24, 'feels_like': 78.76, 'temp_min': 75.24, 'temp_max': 75.24, 'pressure': 1010, 'humidity': 93, 'sea_level': 1010, 'grnd_level': 1008}, 'visibility': 3194, 'wind': {'speed': 10.16, 'deg': 330}, 'clouds': {'all': 98}, 'dt': 1612049196, 'sys': {'country': 'ID', 'sunrise': 1612048562, 'sunset': 1612092753}, 'timezone': 25200, 'id': 1649150, 'name': 'Bengkulu', 'cod': 200}
# ushuaia
# {'coord': {'lon': -68.3, 'lat': -54.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 51.8, 'feels_like': 35.82, 'temp_min': 51.8, 'temp_max': 51.8, 'pressure': 1009, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 24.16, 'deg': 230}, 'clouds': {'all': 20}, 'dt': 1612049196, 'sys': {'type': 1, 'id': 8303, 'country': 'AR', 'sunrise': 1611996787, 'sunset': 1612053588}, 'timezone': -10800, 'id': 3833367, 'name': 'Ushuaia', 'cod': 200}
# jamestown
# {'coord': {'lon': -79.2353, 'lat': 42.097}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 17.89, 'feels_like': 11.03, 'temp_min': 15.8, 'temp_max': 19, 'pressure': 1024, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 2.01, 'deg': 52}, 'clouds': {'all': 1}, 'dt': 1612049016, 'sys': {'type': 1, 'id': 4588, 'country': 'US', 'sunrise': 1612009902, 'sunset': 1612045723}, 'timezone': -18000, 'id': 5122534, 'name': 'Jamestown', 'cod': 200}
# sao francisco
# {'coord': {'lon': -44.8644, 'lat': -15.9486}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.9, 'feels_like': 81.39, 'temp_min': 79.9, 'temp_max': 79.9, 'pressure': 1011, 'humidity': 49, 'sea_level': 1011, 'grnd_level': 959}, 'visibility': 10000, 'wind': {'speed': 2.51, 'deg': 117}, 'clouds': {'all': 70}, 'dt': 1612049197, 'sys': {'country': 'BR', 'sunrise': 1611996498, 'sunset': 1612042627}, 'timezone': -10800, 'id': 3449176, 'name': 'São Francisco', 'cod': 200}
# la libertad
# {'coord': {'lon': -80.9, 'lat': -2.2333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 81, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1008, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 250}, 'clouds': {'all': 75}, 'dt': 1612048924, 'sys': {'type': 1, 'id': 8538, 'country': 'EC', 'sunrise': 1612006233, 'sunset': 1612050191}, 'timezone': -18000, 'id': 3655131, 'name': 'La Libertad', 'cod': 200}
# kavieng
# {'coord': {'lon': 150.7967, 'lat': -2.5744}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 83.34, 'feels_like': 84.58, 'temp_min': 83.34, 'temp_max': 83.34, 'pressure': 1008, 'humidity': 72, 'sea_level': 1008, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 14.5, 'deg': 6}, 'clouds': {'all': 99}, 'dt': 1612049197, 'sys': {'country': 'PG', 'sunrise': 1612037005, 'sunset': 1612081012}, 'timezone': 36000, 'id': 2094342, 'name': 'Kavieng', 'cod': 200}
# wattegama
# {'coord': {'lon': 81.4808, 'lat': 6.7989}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 74.28, 'feels_like': 79.03, 'temp_min': 74.28, 'temp_max': 74.28, 'pressure': 1010, 'humidity': 85, 'sea_level': 1010, 'grnd_level': 996}, 'visibility': 10000, 'wind': {'speed': 4.65, 'deg': 356}, 'clouds': {'all': 97}, 'dt': 1612049197, 'sys': {'country': 'LK', 'sunrise': 1612054349, 'sunset': 1612096943}, 'timezone': 19800, 'id': 1224061, 'name': 'Wattegama', 'cod': 200}
# vaini
# {'coord': {'lon': -175.2, 'lat': -21.2}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 90.45, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1007, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 10}, 'clouds': {'all': 75}, 'dt': 1612049198, 'sys': {'type': 1, 'id': 7285, 'country': 'TO', 'sunrise': 1612113777, 'sunset': 1612160735}, 'timezone': 46800, 'id': 4032243, 'name': 'Vaini', 'cod': 200}
# sentyabrskiy
# {'cod': '404', 'message': 'city not found'}
# butaritari
# {'coord': {'lon': 172.7902, 'lat': 3.0707}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 81.16, 'feels_like': 80.44, 'temp_min': 81.16, 'temp_max': 81.16, 'pressure': 1007, 'humidity': 77, 'sea_level': 1007, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 17.87, 'deg': 69}, 'clouds': {'all': 67}, 'dt': 1612049198, 'sys': {'country': 'KI', 'sunrise': 1612032152, 'sunset': 1612075307}, 'timezone': 43200, 'id': 2110227, 'name': 'Butaritari', 'cod': 200}
# upernavik
# {'coord': {'lon': -56.1549, 'lat': 72.7868}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -9.51, 'feels_like': -20, 'temp_min': -9.51, 'temp_max': -9.51, 'pressure': 1017, 'humidity': 85, 'sea_level': 1017, 'grnd_level': 1017}, 'visibility': 10000, 'wind': {'speed': 6.69, 'deg': 19}, 'clouds': {'all': 37}, 'dt': 1612049198, 'sys': {'country': 'GL', 'sunrise': 1612018892, 'sunset': 1612025653}, 'timezone': -10800, 'id': 3418910, 'name': 'Upernavik', 'cod': 200}
# albany
# {'coord': {'lon': -73.9662, 'lat': 42.6001}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 17.02, 'feels_like': 8.11, 'temp_min': 16, 'temp_max': 18, 'pressure': 1022, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 5.01, 'deg': 272, 'gust': 14}, 'clouds': {'all': 14}, 'dt': 1612049198, 'sys': {'type': 3, 'id': 19530, 'country': 'US', 'sunrise': 1612008708, 'sunset': 1612044388}, 'timezone': -18000, 'id': 5106841, 'name': 'Albany', 'cod': 200}
# kapaa
# {'coord': {'lon': -159.319, 'lat': 22.0752}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 75.09, 'feels_like': 71.02, 'temp_min': 75, 'temp_max': 75.2, 'pressure': 1019, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 60}, 'rain': {'1h': 0.13}, 'clouds': {'all': 75}, 'dt': 1612049199, 'sys': {'type': 1, 'id': 7873, 'country': 'US', 'sunrise': 1612026969, 'sunset': 1612067101}, 'timezone': -36000, 'id': 5848280, 'name': 'Kapaa', 'cod': 200}
# pevek
# {'coord': {'lon': 170.3133, 'lat': 69.7008}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': -32.84, 'feels_like': -42, 'temp_min': -32.84, 'temp_max': -32.84, 'pressure': 1037, 'humidity': 84, 'sea_level': 1037, 'grnd_level': 1030}, 'visibility': 10000, 'wind': {'speed': 3.74, 'deg': 189}, 'clouds': {'all': 2}, 'dt': 1612049199, 'sys': {'country': 'RU', 'sunrise': 1612045620, 'sunset': 1612063028}, 'timezone': 43200, 'id': 2122090, 'name': 'Pevek', 'cod': 200}
# atuona
# {'coord': {'lon': -139.0333, 'lat': -9.8}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 79.23, 'feels_like': 76.53, 'temp_min': 79.23, 'temp_max': 79.23, 'pressure': 1010, 'humidity': 74, 'sea_level': 1010, 'grnd_level': 1002}, 'visibility': 10000, 'wind': {'speed': 18.54, 'deg': 103}, 'clouds': {'all': 21}, 'dt': 1612049199, 'sys': {'country': 'PF', 'sunrise': 1612019604, 'sunset': 1612064727}, 'timezone': -34200, 'id': 4020109, 'name': 'Atuona', 'cod': 200}
# mataura
# {'coord': {'lon': 168.8643, 'lat': -46.1927}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 66.88, 'feels_like': 64.42, 'temp_min': 66.88, 'temp_max': 66.88, 'pressure': 1021, 'humidity': 46, 'sea_level': 1021, 'grnd_level': 1014}, 'visibility': 10000, 'wind': {'speed': 2.48, 'deg': 21}, 'clouds': {'all': 78}, 'dt': 1612049199, 'sys': {'country': 'NZ', 'sunrise': 1612028159, 'sunset': 1612081185}, 'timezone': 46800, 'id': 6201424, 'name': 'Mataura', 'cod': 200}
# bandarbeyla
# {'coord': {'lon': 50.8122, 'lat': 9.4942}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 73.54, 'feels_like': 70.48, 'temp_min': 73.54, 'temp_max': 73.54, 'pressure': 1014, 'humidity': 74, 'sea_level': 1014, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 14.63, 'deg': 42}, 'clouds': {'all': 26}, 'dt': 1612049199, 'sys': {'country': 'SO', 'sunrise': 1612061915, 'sunset': 1612104100}, 'timezone': 10800, 'id': 64814, 'name': 'Bandarbeyla', 'cod': 200}
# lamu
# {'coord': {'lon': 40.902, 'lat': -2.2717}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 77, 'feels_like': 80.83, 'temp_min': 77, 'temp_max': 77, 'pressure': 1011, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 110}, 'clouds': {'all': 1}, 'dt': 1612049199, 'sys': {'type': 1, 'id': 5604, 'country': 'KE', 'sunrise': 1612063407, 'sunset': 1612107366}, 'timezone': 10800, 'id': 189741, 'name': 'Lamu', 'cod': 200}
# lahad datu
# {'coord': {'lon': 118.327, 'lat': 5.0268}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.09, 'feels_like': 80.62, 'temp_min': 75.09, 'temp_max': 75.09, 'pressure': 1011, 'humidity': 90, 'sea_level': 1011, 'grnd_level': 1009}, 'visibility': 6152, 'wind': {'speed': 5.55, 'deg': 358}, 'clouds': {'all': 100}, 'dt': 1612049199, 'sys': {'country': 'MY', 'sunrise': 1612045372, 'sunset': 1612088232}, 'timezone': 28800, 'id': 1733953, 'name': 'Lahad Datu', 'cod': 200}
# chuy
# {'coord': {'lon': -53.4616, 'lat': -33.6971}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 74.03, 'feels_like': 72.63, 'temp_min': 74.03, 'temp_max': 74.03, 'pressure': 1010, 'humidity': 79, 'sea_level': 1010, 'grnd_level': 1007}, 'visibility': 10000, 'wind': {'speed': 13.53, 'deg': 108}, 'rain': {'1h': 2.1772}, 'clouds': {'all': 52}, 'dt': 1612049199, 'sys': {'country': 'UY', 'sunrise': 1611996845, 'sunset': 1612046407}, 'timezone': -10800, 'id': 3443061, 'name': 'Chui', 'cod': 200}
# vardo
# {'coord': {'lon': 31.1107, 'lat': 70.3705}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 24.62, 'feels_like': 9, 'temp_min': 24.62, 'temp_max': 24.62, 'pressure': 996, 'humidity': 95, 'sea_level': 996, 'grnd_level': 995}, 'visibility': 903, 'wind': {'speed': 19.46, 'deg': 80}, 'snow': {'1h': 0.17}, 'clouds': {'all': 100}, 'dt': 1612049199, 'sys': {'country': 'NO', 'sunrise': 1612079615, 'sunset': 1612095858}, 'timezone': 3600, 'id': 777019, 'name': 'Vardø', 'cod': 200}
# saint-augustin
# {'coord': {'lon': -58.6502, 'lat': 51.226}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 28.89, 'feels_like': 15.82, 'temp_min': 28.89, 'temp_max': 28.89, 'pressure': 1010, 'humidity': 94, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 15.75, 'deg': 346}, 'clouds': {'all': 90}, 'dt': 1612049199, 'sys': {'country': 'CA', 'sunrise': 1612006477, 'sunset': 1612039266}, 'timezone': -14400, 'id': 6137462, 'name': 'Saint-Augustin', 'cod': 200}
# aquiraz
# {'coord': {'lon': -38.3911, 'lat': -3.9014}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 87.69, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1012, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 80}, 'clouds': {'all': 0}, 'dt': 1612049199, 'sys': {'type': 1, 'id': 8363, 'country': 'BR', 'sunrise': 1611995902, 'sunset': 1612040115}, 'timezone': -10800, 'id': 3407407, 'name': 'Aquiraz', 'cod': 200}
# georgetown
# {'coord': {'lon': 100.3354, 'lat': 5.4112}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 75.43, 'feels_like': 79, 'temp_min': 73, 'temp_max': 77, 'pressure': 1010, 'humidity': 83}, 'visibility': 8000, 'wind': {'speed': 7.14, 'deg': 74}, 'clouds': {'all': 20}, 'dt': 1612049177, 'sys': {'type': 1, 'id': 9429, 'country': 'MY', 'sunrise': 1612049719, 'sunset': 1612092522}, 'timezone': 28800, 'id': 1735106, 'name': 'George Town', 'cod': 200}
# korla
# {'coord': {'lon': 86.1469, 'lat': 41.7597}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 20.37, 'feels_like': 12.09, 'temp_min': 20.37, 'temp_max': 20.37, 'pressure': 1029, 'humidity': 83, 'sea_level': 1029, 'grnd_level': 913}, 'visibility': 10000, 'wind': {'speed': 5.21, 'deg': 229}, 'clouds': {'all': 0}, 'dt': 1612049199, 'sys': {'country': 'CN', 'sunrise': 1612056532, 'sunset': 1612092520}, 'timezone': 28800, 'id': 1529376, 'name': 'Korla', 'cod': 200}
# port alfred
# {'coord': {'lon': 26.891, 'lat': -33.5906}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 64, 'feels_like': 66.85, 'temp_min': 64, 'temp_max': 64, 'pressure': 1010, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 1.86, 'deg': 290}, 'clouds': {'all': 20}, 'dt': 1612049200, 'sys': {'type': 3, 'id': 2011314, 'country': 'ZA', 'sunrise': 1612064019, 'sunset': 1612113479}, 'timezone': 7200, 'id': 964432, 'name': 'Port Alfred', 'cod': 200}
# hilo
# {'coord': {'lon': -155.09, 'lat': 19.7297}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 76.01, 'feels_like': 75.27, 'temp_min': 72, 'temp_max': 80.6, 'pressure': 1018, 'humidity': 57}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 0}, 'rain': {'1h': 0.22}, 'clouds': {'all': 1}, 'dt': 1612048958, 'sys': {'type': 1, 'id': 7881, 'country': 'US', 'sunrise': 1612025753, 'sunset': 1612066286}, 'timezone': -36000, 'id': 5855927, 'name': 'Hilo', 'cod': 200}
# neuquen
# {'coord': {'lon': -68.0591, 'lat': -38.9516}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 66.2, 'feels_like': 58.91, 'temp_min': 66.2, 'temp_max': 66.2, 'pressure': 1016, 'humidity': 59}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 70}, 'clouds': {'all': 75}, 'dt': 1612048965, 'sys': {'type': 1, 'id': 8310, 'country': 'AR', 'sunrise': 1611999697, 'sunset': 1612050563}, 'timezone': -10800, 'id': 3843123, 'name': 'Neuquén', 'cod': 200}
# nisia floresta
# {'coord': {'lon': -35.2086, 'lat': -6.0911}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 79.74, 'feels_like': 82.71, 'temp_min': 78.8, 'temp_max': 80.6, 'pressure': 1013, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 130}, 'clouds': {'all': 20}, 'dt': 1612049200, 'sys': {'type': 1, 'id': 8417, 'country': 'BR', 'sunrise': 1611994970, 'sunset': 1612039520}, 'timezone': -10800, 'id': 3393922, 'name': 'Nísia Floresta', 'cod': 200}
# punta arenas
# {'coord': {'lon': -70.9167, 'lat': -53.15}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 53.29, 'feels_like': 38.23, 'temp_min': 53.01, 'temp_max': 53.6, 'pressure': 1014, 'humidity': 62}, 'visibility': 10000, 'wind': {'speed': 23.02, 'deg': 240}, 'clouds': {'all': 0}, 'dt': 1612049200, 'sys': {'type': 1, 'id': 8487, 'country': 'CL', 'sunrise': 1611997840, 'sunset': 1612053792}, 'timezone': -10800, 'id': 3874787, 'name': 'Punta Arenas', 'cod': 200}
# haines junction
# {'coord': {'lon': -137.5108, 'lat': 60.7522}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': -0.4, 'feels_like': -8.32, 'temp_min': -0.4, 'temp_max': -0.4, 'pressure': 1016, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 240}, 'clouds': {'all': 100}, 'dt': 1612049200, 'sys': {'type': 1, 'id': 287, 'country': 'CA', 'sunrise': 1612027911, 'sunset': 1612055690}, 'timezone': -25200, 'id': 5969025, 'name': 'Haines Junction', 'cod': 200}
# rikitea
# {'coord': {'lon': -134.9692, 'lat': -23.1203}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 79.12, 'feels_like': 79.86, 'temp_min': 79.12, 'temp_max': 79.12, 'pressure': 1015, 'humidity': 74, 'sea_level': 1015, 'grnd_level': 1012}, 'visibility': 10000, 'wind': {'speed': 12.33, 'deg': 101}, 'rain': {'1h': 0.14}, 'clouds': {'all': 22}, 'dt': 1612049200, 'sys': {'country': 'PF', 'sunrise': 1612017504, 'sunset': 1612064876}, 'timezone': -32400, 'id': 4030556, 'name': 'Rikitea', 'cod': 200}
# bredasdorp
# {'coord': {'lon': 20.0403, 'lat': -34.5322}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.99, 'feels_like': 67.73, 'temp_min': 66.99, 'temp_max': 66.99, 'pressure': 1011, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 6.35, 'deg': 299}, 'clouds': {'all': 6}, 'dt': 1612049188, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1612065556, 'sunset': 1612115231}, 'timezone': 7200, 'id': 1015776, 'name': 'Bredasdorp', 'cod': 200}
# puerto ayora
# {'coord': {'lon': -90.3518, 'lat': -0.7393}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 81.52, 'feels_like': 82.42, 'temp_min': 80.01, 'temp_max': 84.2, 'pressure': 1007, 'humidity': 70}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 120}, 'clouds': {'all': 0}, 'dt': 1612049200, 'sys': {'type': 1, 'id': 8521, 'country': 'EC', 'sunrise': 1612008616, 'sunset': 1612052346}, 'timezone': -21600, 'id': 3652764, 'name': 'Puerto Ayora', 'cod': 200}
# talnakh
# {'coord': {'lon': 88.3972, 'lat': 69.4865}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -31.13, 'feels_like': -41.84, 'temp_min': -31.13, 'temp_max': -31.13, 'pressure': 1047, 'humidity': 70, 'sea_level': 1047, 'grnd_level': 1037}, 'visibility': 10000, 'wind': {'speed': 6.46, 'deg': 129}, 'clouds': {'all': 0}, 'dt': 1612049200, 'sys': {'country': 'RU', 'sunrise': 1612064996, 'sunset': 1612082976}, 'timezone': 25200, 'id': 1490256, 'name': 'Talnakh', 'cod': 200}
# busselton
# {'coord': {'lon': 115.3333, 'lat': -33.65}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 65.75, 'feels_like': 67.33, 'temp_min': 62.01, 'temp_max': 68, 'pressure': 1014, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 1.01, 'deg': 97, 'gust': 5.99}, 'clouds': {'all': 0}, 'dt': 1612049200, 'sys': {'type': 3, 'id': 2008303, 'country': 'AU', 'sunrise': 1612042772, 'sunset': 1612092270}, 'timezone': 28800, 'id': 2075265, 'name': 'Busselton', 'cod': 200}
# balykshi
# {'coord': {'lon': 51.8667, 'lat': 47.0667}, 'weather': [{'id': 741, 'main': 'Fog', 'description': 'fog', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 30.2, 'feels_like': 20.07, 'temp_min': 30.2, 'temp_max': 30.2, 'pressure': 1014, 'humidity': 100}, 'visibility': 550, 'wind': {'speed': 11.18, 'deg': 70}, 'clouds': {'all': 90}, 'dt': 1612049200, 'sys': {'type': 1, 'id': 8836, 'country': 'KZ', 'sunrise': 1612065543, 'sunset': 1612099965}, 'timezone': 18000, 'id': 610445, 'name': 'Balyqshy', 'cod': 200}
# samusu
# {'cod': '404', 'message': 'city not found'}
# clarence town
# {'coord': {'lon': 151.7833, 'lat': -32.5833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 75.4, 'feels_like': 79.95, 'temp_min': 75, 'temp_max': 75.99, 'pressure': 1014, 'humidity': 88}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 230}, 'clouds': {'all': 90}, 'dt': 1612049200, 'sys': {'type': 1, 'id': 9605, 'country': 'AU', 'sunrise': 1612034138, 'sunset': 1612083405}, 'timezone': 39600, 'id': 2171465, 'name': 'Clarence Town', 'cod': 200}
# carhuaz
# {'coord': {'lon': -77.6447, 'lat': -9.2819}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 59.45, 'feels_like': 55.96, 'temp_min': 59.45, 'temp_max': 59.45, 'pressure': 1013, 'humidity': 61, 'sea_level': 1013, 'grnd_level': 745}, 'visibility': 2999, 'wind': {'speed': 4.54, 'deg': 263}, 'rain': {'1h': 1.56}, 'clouds': {'all': 83}, 'dt': 1612049201, 'sys': {'country': 'PE', 'sunrise': 1612004908, 'sunset': 1612049954}, 'timezone': -18000, 'id': 3698814, 'name': 'Carhuaz', 'cod': 200}
# port elizabeth
# {'coord': {'lon': 25.5701, 'lat': -33.918}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 64.4, 'feels_like': 66.11, 'temp_min': 64.4, 'temp_max': 64.4, 'pressure': 1011, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 340}, 'clouds': {'all': 0}, 'dt': 1612049201, 'sys': {'type': 1, 'id': 1973, 'country': 'ZA', 'sunrise': 1612064299, 'sunset': 1612113833}, 'timezone': 7200, 'id': 964420, 'name': 'Port Elizabeth', 'cod': 200}
# norman wells
# {'coord': {'lon': -126.8329, 'lat': 65.282}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': -27.4, 'feels_like': -36.36, 'temp_min': -27.4, 'temp_max': -27.4, 'pressure': 1025, 'humidity': 75}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 260}, 'clouds': {'all': 20}, 'dt': 1612049201, 'sys': {'type': 1, 'id': 951, 'country': 'CA', 'sunrise': 1612027344, 'sunset': 1612051130}, 'timezone': -25200, 'id': 6089245, 'name': 'Norman Wells', 'cod': 200}
# alofi
# {'coord': {'lon': -169.9187, 'lat': -19.0595}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 82.4, 'feels_like': 85.53, 'temp_min': 82.4, 'temp_max': 82.4, 'pressure': 1009, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 10}, 'rain': {'1h': 1.79}, 'clouds': {'all': 100}, 'dt': 1612049170, 'sys': {'type': 1, 'id': 7306, 'country': 'NU', 'sunrise': 1612026258, 'sunset': 1612072900}, 'timezone': -39600, 'id': 4036284, 'name': 'Alofi', 'cod': 200}
# yulara
# {'coord': {'lon': 130.9889, 'lat': -25.2406}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03d'}], 'base': 'stations', 'main': {'temp': 84.2, 'feels_like': 73.92, 'temp_min': 84.2, 'temp_max': 84.2, 'pressure': 1011, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 90}, 'clouds': {'all': 45}, 'dt': 1612049201, 'sys': {'type': 1, 'id': 9487, 'country': 'AU', 'sunrise': 1612039887, 'sunset': 1612087639}, 'timezone': 34200, 'id': 6355222, 'name': 'Yulara', 'cod': 200}
# new norfolk
# {'coord': {'lon': 147.0587, 'lat': -42.7826}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 61.77, 'feels_like': 59.13, 'temp_min': 57.99, 'temp_max': 66.99, 'pressure': 1017, 'humidity': 56}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 327, 'gust': 10}, 'clouds': {'all': 15}, 'dt': 1612049172, 'sys': {'type': 3, 'id': 2031307, 'country': 'AU', 'sunrise': 1612033952, 'sunset': 1612085860}, 'timezone': 39600, 'id': 2155415, 'name': 'New Norfolk', 'cod': 200}
# mahebourg
# {'coord': {'lon': 57.7, 'lat': -20.4081}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 87.37, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1013, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 120}, 'clouds': {'all': 40}, 'dt': 1612049182, 'sys': {'type': 1, 'id': 2061, 'country': 'MU', 'sunrise': 1612057926, 'sunset': 1612104782}, 'timezone': 14400, 'id': 934322, 'name': 'Mahébourg', 'cod': 200}
# saint george
# {'coord': {'lon': -113.5841, 'lat': 37.1041}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 50.74, 'feels_like': 46.04, 'temp_min': 48.2, 'temp_max': 53.01, 'pressure': 1023, 'humidity': 49}, 'visibility': 10000, 'wind': {'speed': 2.06, 'deg': 312}, 'clouds': {'all': 1}, 'dt': 1612049024, 'sys': {'type': 1, 'id': 5832, 'country': 'US', 'sunrise': 1612017502, 'sunset': 1612054612}, 'timezone': -25200, 'id': 5546220, 'name': 'Saint George', 'cod': 200}
# yinchuan
# {'coord': {'lon': 106.2731, 'lat': 38.4681}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 27.43, 'feels_like': 17.55, 'temp_min': 27.43, 'temp_max': 27.43, 'pressure': 1026, 'humidity': 69, 'sea_level': 1026, 'grnd_level': 893}, 'visibility': 10000, 'wind': {'speed': 8.43, 'deg': 247}, 'clouds': {'all': 0}, 'dt': 1612049201, 'sys': {'country': 'CN', 'sunrise': 1612051282, 'sunset': 1612088109}, 'timezone': 28800, 'id': 1786657, 'name': 'Yinchuan', 'cod': 200}
# nouadhibou
# {'coord': {'lon': -17.0347, 'lat': 20.931}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 68, 'feels_like': 59.29, 'temp_min': 68, 'temp_max': 68, 'pressure': 1018, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 18.41, 'deg': 20}, 'clouds': {'all': 0}, 'dt': 1612049201, 'sys': {'type': 1, 'id': 2444, 'country': 'MR', 'sunrise': 1611992729, 'sunset': 1612033037}, 'timezone': 0, 'id': 2377457, 'name': 'Nouadhibou', 'cod': 200}
# sapa
# {'coord': {'lon': 120.3241, 'lat': 5.1544}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 79.66, 'feels_like': 83.41, 'temp_min': 79.66, 'temp_max': 79.66, 'pressure': 1010, 'humidity': 82, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 9864, 'wind': {'speed': 10.38, 'deg': 42}, 'rain': {'1h': 3.1348}, 'clouds': {'all': 100}, 'dt': 1612049202, 'sys': {'country': 'PH', 'sunrise': 1612044902, 'sunset': 1612087743}, 'timezone': 28800, 'id': 1687343, 'name': 'Sapa', 'cod': 200}
# lompoc
# {'coord': {'lon': -120.4579, 'lat': 34.6391}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 55.81, 'feels_like': 51.91, 'temp_min': 51.01, 'temp_max': 59, 'pressure': 1021, 'humidity': 58}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 140}, 'clouds': {'all': 1}, 'dt': 1612049202, 'sys': {'type': 1, 'id': 4747, 'country': 'US', 'sunrise': 1612018868, 'sunset': 1612056546}, 'timezone': -28800, 'id': 5367788, 'name': 'Lompoc', 'cod': 200}
# thompson
# {'coord': {'lon': -97.8558, 'lat': 55.7435}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 14, 'feels_like': 7.07, 'temp_min': 14, 'temp_max': 14, 'pressure': 1021, 'humidity': 92}, 'visibility': 10000, 'wind': {'speed': 2.3, 'deg': 50}, 'clouds': {'all': 90}, 'dt': 1612049202, 'sys': {'type': 1, 'id': 935, 'country': 'CA', 'sunrise': 1612016896, 'sunset': 1612047668}, 'timezone': -21600, 'id': 6165406, 'name': 'Thompson', 'cod': 200}
# hobart
# {'coord': {'lon': 147.3294, 'lat': -42.8794}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 66.31, 'feels_like': 59.79, 'temp_min': 64.4, 'temp_max': 66.99, 'pressure': 1017, 'humidity': 45}, 'visibility': 10000, 'wind': {'speed': 9.22, 'deg': 330}, 'clouds': {'all': 20}, 'dt': 1612049182, 'sys': {'type': 1, 'id': 9545, 'country': 'AU', 'sunrise': 1612033872, 'sunset': 1612085809}, 'timezone': 39600, 'id': 2163355, 'name': 'Hobart', 'cod': 200}
# belushya guba
# {'cod': '404', 'message': 'city not found'}
# leningradskiy
# {'coord': {'lon': 178.4167, 'lat': 69.3833}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': -27.51, 'feels_like': -36.35, 'temp_min': -27.51, 'temp_max': -27.51, 'pressure': 1038, 'humidity': 81, 'sea_level': 1038, 'grnd_level': 1038}, 'visibility': 10000, 'wind': {'speed': 3.24, 'deg': 159}, 'clouds': {'all': 0}, 'dt': 1612049201, 'sys': {'country': 'RU', 'sunrise': 1612043370, 'sunset': 1612061388}, 'timezone': 43200, 'id': 2123814, 'name': 'Leningradskiy', 'cod': 200}
# khatanga
# {'coord': {'lon': 102.5, 'lat': 71.9667}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': -46.59, 'feels_like': -54.11, 'temp_min': -46.59, 'temp_max': -46.59, 'pressure': 1049, 'humidity': 78, 'sea_level': 1049, 'grnd_level': 1044}, 'visibility': 10000, 'wind': {'speed': 0.67, 'deg': 335}, 'clouds': {'all': 31}, 'dt': 1612049202, 'sys': {'country': 'RU', 'sunrise': 1612064845, 'sunset': 1612076357}, 'timezone': 25200, 'id': 2022572, 'name': 'Khatanga', 'cod': 200}
# saskylakh
# {'coord': {'lon': 114.0833, 'lat': 71.9167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -34.65, 'feels_like': -47.51, 'temp_min': -34.65, 'temp_max': -34.65, 'pressure': 1043, 'humidity': 82, 'sea_level': 1043, 'grnd_level': 1042}, 'visibility': 4343, 'wind': {'speed': 10.27, 'deg': 328}, 'clouds': {'all': 100}, 'dt': 1612049202, 'sys': {'country': 'RU', 'sunrise': 1612061991, 'sunset': 1612073651}, 'timezone': 32400, 'id': 2017155, 'name': 'Saskylakh', 'cod': 200}
# hasaki
# {'coord': {'lon': 140.8333, 'lat': 35.7333}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 31.8, 'feels_like': 24.31, 'temp_min': 28.4, 'temp_max': 33.8, 'pressure': 1023, 'humidity': 64}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 250}, 'clouds': {'all': 20}, 'dt': 1612049202, 'sys': {'type': 1, 'id': 7955, 'country': 'JP', 'sunrise': 1612042670, 'sunset': 1612080130}, 'timezone': 32400, 'id': 2112802, 'name': 'Hasaki', 'cod': 200}
# nzega
# {'coord': {'lon': 29.5564, 'lat': -2.479}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 54.75, 'feels_like': 53.89, 'temp_min': 54.75, 'temp_max': 54.75, 'pressure': 1013, 'humidity': 93, 'sea_level': 1013, 'grnd_level': 800}, 'visibility': 10000, 'wind': {'speed': 3.09, 'deg': 253}, 'clouds': {'all': 58}, 'dt': 1612049202, 'sys': {'country': 'RW', 'sunrise': 1612066114, 'sunset': 1612110104}, 'timezone': 7200, 'id': 201865, 'name': 'Nzega', 'cod': 200}
# murgab
# {'coord': {'lon': 61.9714, 'lat': 37.4966}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 48.2, 'feels_like': 42.57, 'temp_min': 48.2, 'temp_max': 48.2, 'pressure': 1008, 'humidity': 61}, 'visibility': 6000, 'wind': {'speed': 4.61, 'deg': 310}, 'clouds': {'all': 75}, 'dt': 1612049172, 'sys': {'type': 1, 'id': 8990, 'country': 'TM', 'sunrise': 1612061791, 'sunset': 1612098867}, 'timezone': 18000, 'id': 1218612, 'name': 'Murgab', 'cod': 200}
# bokoro
# {'coord': {'lon': 17.0568, 'lat': 12.3807}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 73.33, 'feels_like': 62.28, 'temp_min': 73.33, 'temp_max': 73.33, 'pressure': 1011, 'humidity': 20, 'sea_level': 1011, 'grnd_level': 976}, 'visibility': 10000, 'wind': {'speed': 12.73, 'deg': 15}, 'clouds': {'all': 1}, 'dt': 1612049202, 'sys': {'country': 'TD', 'sunrise': 1612070239, 'sunset': 1612111981}, 'timezone': 3600, 'id': 2434985, 'name': 'Bokoro', 'cod': 200}
# pochinki
# {'coord': {'lon': 44.8668, 'lat': 54.6988}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 20.16, 'feels_like': 9.48, 'temp_min': 20.16, 'temp_max': 20.16, 'pressure': 1007, 'humidity': 96, 'sea_level': 1007, 'grnd_level': 990}, 'visibility': 10000, 'wind': {'speed': 9.95, 'deg': 167}, 'clouds': {'all': 100}, 'dt': 1612049202, 'sys': {'country': 'RU', 'sunrise': 1612068722, 'sunset': 1612100147}, 'timezone': 10800, 'id': 508635, 'name': 'Pochinki', 'cod': 200}
# severo-kurilsk
# {'coord': {'lon': 156.125, 'lat': 50.6789}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 24.8, 'feels_like': 3.81, 'temp_min': 24.8, 'temp_max': 24.8, 'pressure': 978, 'humidity': 95, 'sea_level': 978, 'grnd_level': 978}, 'visibility': 1838, 'wind': {'speed': 29.04, 'deg': 324}, 'snow': {'1h': 0.33}, 'clouds': {'all': 96}, 'dt': 1612049202, 'sys': {'country': 'RU', 'sunrise': 1612041188, 'sunset': 1612074271}, 'timezone': 39600, 'id': 2121385, 'name': "Severo-Kuril'sk", 'cod': 200}
# preeceville
# {'coord': {'lon': -102.6677, 'lat': 51.95}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 13.14, 'feels_like': 5.9, 'temp_min': 13.14, 'temp_max': 13.14, 'pressure': 1022, 'humidity': 96, 'sea_level': 1022, 'grnd_level': 957}, 'visibility': 2836, 'wind': {'speed': 2.84, 'deg': 290}, 'clouds': {'all': 99}, 'dt': 1612049203, 'sys': {'country': 'CA', 'sunrise': 1612017178, 'sunset': 1612049696}, 'timezone': -21600, 'id': 6112862, 'name': 'Preeceville', 'cod': 200}
# chapais
# {'coord': {'lon': -74.8492, 'lat': 49.7834}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -4, 'feels_like': -15.16, 'temp_min': -4, 'temp_max': -4, 'pressure': 1025, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 330}, 'clouds': {'all': 90}, 'dt': 1612049203, 'sys': {'type': 1, 'id': 859, 'country': 'CA', 'sunrise': 1612010081, 'sunset': 1612043438}, 'timezone': -18000, 'id': 5919850, 'name': 'Chapais', 'cod': 200}
# moron
# {'coord': {'lon': -58.6198, 'lat': -34.6534}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 63.61, 'feels_like': 64.74, 'temp_min': 62.01, 'temp_max': 64.99, 'pressure': 1016, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 171, 'gust': 11.01}, 'rain': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1612049203, 'sys': {'type': 3, 'id': 2008838, 'country': 'AR', 'sunrise': 1611997972, 'sunset': 1612047757}, 'timezone': -10800, 'id': 3430545, 'name': 'Morón', 'cod': 200}
# los llanos de aridane
# {'coord': {'lon': -17.9182, 'lat': 28.6585}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 61.72, 'feels_like': 55.31, 'temp_min': 60.01, 'temp_max': 64.4, 'pressure': 1028, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 13.8, 'deg': 10}, 'clouds': {'all': 90}, 'dt': 1612049203, 'sys': {'type': 1, 'id': 2377, 'country': 'ES', 'sunrise': 1611993647, 'sunset': 1612032542}, 'timezone': 0, 'id': 2514651, 'name': 'Los Llanos de Aridane', 'cod': 200}
# barentsburg
# {'cod': '404', 'message': 'city not found'}
# nabire
# {'coord': {'lon': 135.4833, 'lat': -3.3667}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 77.43, 'feels_like': 85.44, 'temp_min': 77.43, 'temp_max': 77.43, 'pressure': 1010, 'humidity': 88, 'sea_level': 1010, 'grnd_level': 1010}, 'visibility': 10000, 'wind': {'speed': 2.73, 'deg': 156}, 'clouds': {'all': 100}, 'dt': 1612049203, 'sys': {'country': 'ID', 'sunrise': 1612040621, 'sunset': 1612084747}, 'timezone': 32400, 'id': 1634614, 'name': 'Nabire', 'cod': 200}
# esperance
# {'coord': {'lon': 121.9, 'lat': -33.8667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 62.6, 'feels_like': 57.11, 'temp_min': 62.6, 'temp_max': 62.6, 'pressure': 1016, 'humidity': 77}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 30}, 'clouds': {'all': 0}, 'dt': 1612049203, 'sys': {'type': 1, 'id': 9525, 'country': 'AU', 'sunrise': 1612041170, 'sunset': 1612090719}, 'timezone': 28800, 'id': 2071860, 'name': 'Esperance', 'cod': 200}
# broome
# {'coord': {'lon': -75.833, 'lat': 42.2506}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 14.32, 'feels_like': 3.85, 'temp_min': 12.99, 'temp_max': 15.8, 'pressure': 1023, 'humidity': 73}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 340}, 'clouds': {'all': 1}, 'dt': 1612049203, 'sys': {'type': 1, 'id': 3429, 'country': 'US', 'sunrise': 1612009107, 'sunset': 1612044885}, 'timezone': -18000, 'id': 5110365, 'name': 'Broome', 'cod': 200}
# kaitangata
# {'coord': {'lon': 169.8464, 'lat': -46.2817}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 60.01, 'feels_like': 53.04, 'temp_min': 60.01, 'temp_max': 60.01, 'pressure': 1020, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 15.01, 'deg': 135, 'gust': 18.01}, 'clouds': {'all': 68}, 'dt': 1612049174, 'sys': {'type': 3, 'id': 2000217, 'country': 'NZ', 'sunrise': 1612027907, 'sunset': 1612080965}, 'timezone': 46800, 'id': 2208248, 'name': 'Kaitangata', 'cod': 200}
# coihaique
# {'coord': {'lon': -72.0662, 'lat': -45.5752}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 71.6, 'feels_like': 64.56, 'temp_min': 71.6, 'temp_max': 71.6, 'pressure': 1014, 'humidity': 30}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 240}, 'clouds': {'all': 0}, 'dt': 1612049203, 'sys': {'type': 1, 'id': 8491, 'country': 'CL', 'sunrise': 1611999659, 'sunset': 1612052525}, 'timezone': -10800, 'id': 3894426, 'name': 'Coyhaique', 'cod': 200}
# brownsville
# {'coord': {'lon': -97.4975, 'lat': 25.9018}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}], 'base': 'stations', 'main': {'temp': 77.86, 'feels_like': 71.55, 'temp_min': 77, 'temp_max': 78.8, 'pressure': 1010, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 20.71, 'deg': 170, 'gust': 29.93}, 'clouds': {'all': 20}, 'dt': 1612049133, 'sys': {'type': 1, 'id': 3496, 'country': 'US', 'sunrise': 1612012478, 'sunset': 1612051914}, 'timezone': -21600, 'id': 4676740, 'name': 'Brownsville', 'cod': 200}
# avarua
# {'coord': {'lon': -159.775, 'lat': -21.2078}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 87.69, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1011, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 5.75, 'deg': 30}, 'rain': {'1h': 0.6}, 'clouds': {'all': 75}, 'dt': 1612049203, 'sys': {'type': 1, 'id': 7271, 'country': 'CK', 'sunrise': 1612023634, 'sunset': 1612070655}, 'timezone': -36000, 'id': 4035715, 'name': 'Avarua', 'cod': 200}
# kibray
# {'coord': {'lon': 69.4641, 'lat': 41.3873}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 44.6, 'feels_like': 34.07, 'temp_min': 44.6, 'temp_max': 44.6, 'pressure': 1011, 'humidity': 53}, 'visibility': 10000, 'wind': {'speed': 11.5, 'deg': 240}, 'clouds': {'all': 0}, 'dt': 1612049204, 'sys': {'type': 1, 'id': 9016, 'country': 'UZ', 'sunrise': 1612060484, 'sunset': 1612096577}, 'timezone': 18000, 'id': 1514210, 'name': 'Kibray', 'cod': 200}
# nikolskoye
# {'coord': {'lon': 30.7861, 'lat': 59.7035}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 26.2, 'feels_like': 16.63, 'temp_min': 25, 'temp_max': 27, 'pressure': 986, 'humidity': 93}, 'visibility': 7000, 'wind': {'speed': 8.95, 'deg': 220}, 'snow': {'1h': 0.75}, 'clouds': {'all': 75}, 'dt': 1612049204, 'sys': {'type': 1, 'id': 8926, 'country': 'RU', 'sunrise': 1612073486, 'sunset': 1612102142}, 'timezone': 10800, 'id': 546105, 'name': 'Nikolskoye', 'cod': 200}
# eureka
# {'coord': {'lon': -124.1637, 'lat': 40.8021}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 53.89, 'feels_like': 52.05, 'temp_min': 51.8, 'temp_max': 55, 'pressure': 1016, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3.44, 'deg': 110}, 'clouds': {'all': 90}, 'dt': 1612048954, 'sys': {'type': 1, 'id': 3217, 'country': 'US', 'sunrise': 1612020502, 'sunset': 1612056691}, 'timezone': -28800, 'id': 5563397, 'name': 'Eureka', 'cod': 200}
# stoyba
# {'cod': '404', 'message': 'city not found'}
# saint-philippe
# {'coord': {'lon': 55.7679, 'lat': -21.3585}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 73.44, 'feels_like': 74.46, 'temp_min': 64.99, 'temp_max': 78.8, 'pressure': 1012, 'humidity': 65}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 30}, 'clouds': {'all': 0}, 'dt': 1612049204, 'sys': {'type': 1, 'id': 2127, 'country': 'RE', 'sunrise': 1612058306, 'sunset': 1612105330}, 'timezone': 14400, 'id': 935215, 'name': 'Saint-Philippe', 'cod': 200}
# tasiilaq
# {'coord': {'lon': -37.6368, 'lat': 65.6145}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 21.2, 'feels_like': 5.09, 'temp_min': 21.2, 'temp_max': 21.2, 'pressure': 1021, 'humidity': 35}, 'visibility': 10000, 'wind': {'speed': 17.27, 'deg': 60}, 'clouds': {'all': 90}, 'dt': 1612049204, 'sys': {'type': 1, 'id': 81, 'country': 'GL', 'sunrise': 1612006172, 'sunset': 1612029484}, 'timezone': -10800, 'id': 3424607, 'name': 'Tasiilaq', 'cod': 200}
# pyay
# {'coord': {'lon': 95.2167, 'lat': 18.8167}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 63.01, 'feels_like': 60.08, 'temp_min': 63.01, 'temp_max': 63.01, 'pressure': 1013, 'humidity': 45, 'sea_level': 1013, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 1.74, 'deg': 244}, 'clouds': {'all': 91}, 'dt': 1612049204, 'sys': {'country': 'MM', 'sunrise': 1612051998, 'sunset': 1612092700}, 'timezone': 23400, 'id': 1299154, 'name': 'Prome', 'cod': 200}
# gambela
# {'coord': {'lon': 34.5833, 'lat': 8.25}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 80.37, 'feels_like': 80.53, 'temp_min': 80.37, 'temp_max': 80.37, 'pressure': 1009, 'humidity': 39, 'sea_level': 1009, 'grnd_level': 960}, 'visibility': 10000, 'wind': {'speed': 1.43, 'deg': 16}, 'clouds': {'all': 9}, 'dt': 1612049204, 'sys': {'country': 'ET', 'sunrise': 1612065715, 'sunset': 1612108091}, 'timezone': 10800, 'id': 337405, 'name': 'Gambēla', 'cod': 200}
# hermanus
# {'coord': {'lon': 19.2345, 'lat': -34.4187}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 66.99, 'feels_like': 65.97, 'temp_min': 66.99, 'temp_max': 66.99, 'pressure': 1011, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 9.48, 'deg': 311}, 'clouds': {'all': 3}, 'dt': 1612049204, 'sys': {'type': 3, 'id': 2006131, 'country': 'ZA', 'sunrise': 1612065763, 'sunset': 1612115411}, 'timezone': 7200, 'id': 3366880, 'name': 'Hermanus', 'cod': 200}
# kaeo
# {'coord': {'lon': 173.7833, 'lat': -35.1}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 73.99, 'feels_like': 69.66, 'temp_min': 73.99, 'temp_max': 73.99, 'pressure': 1021, 'humidity': 50}, 'visibility': 10000, 'wind': {'speed': 10, 'deg': 95, 'gust': 15.99}, 'clouds': {'all': 0}, 'dt': 1612049204, 'sys': {'type': 3, 'id': 2012217, 'country': 'NZ', 'sunrise': 1612028564, 'sunset': 1612078418}, 'timezone': 46800, 'id': 2189343, 'name': 'Kaeo', 'cod': 200}
# airai
# {'coord': {'lon': 125.4092, 'lat': -8.9266}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10d'}], 'base': 'stations', 'main': {'temp': 61.66, 'feels_like': 62.56, 'temp_min': 61.66, 'temp_max': 61.66, 'pressure': 1008, 'humidity': 100, 'sea_level': 1008, 'grnd_level': 854}, 'visibility': 4111, 'wind': {'speed': 5.35, 'deg': 311}, 'rain': {'1h': 3.158}, 'clouds': {'all': 100}, 'dt': 1612049204, 'sys': {'country': 'TL', 'sunrise': 1612042612, 'sunset': 1612087592}, 'timezone': 32400, 'id': 1651810, 'name': 'Airai', 'cod': 200}
# dikson
# {'coord': {'lon': 80.5464, 'lat': 73.5069}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -34.87, 'feels_like': -46.16, 'temp_min': -34.87, 'temp_max': -34.87, 'pressure': 1043, 'humidity': 80, 'sea_level': 1043, 'grnd_level': 1037}, 'visibility': 10000, 'wind': {'speed': 7.47, 'deg': 170}, 'clouds': {'all': 0}, 'dt': 1612049204, 'sys': {'country': 'RU', 'sunrise': 0, 'sunset': 0}, 'timezone': 25200, 'id': 1507390, 'name': 'Dikson', 'cod': 200}
# east london
# {'coord': {'lon': 27.9116, 'lat': -33.0153}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 69.87, 'feels_like': 73.8, 'temp_min': 69.87, 'temp_max': 69.87, 'pressure': 1011, 'humidity': 83, 'sea_level': 1011, 'grnd_level': 1006}, 'visibility': 10000, 'wind': {'speed': 2.01, 'deg': 358}, 'clouds': {'all': 2}, 'dt': 1612049204, 'sys': {'country': 'ZA', 'sunrise': 1612063839, 'sunset': 1612113169}, 'timezone': 7200, 'id': 1006984, 'name': 'East London', 'cod': 200}
# komsomolskiy
# {'coord': {'lon': 71.7189, 'lat': 40.4272}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 37.4, 'feels_like': 28.29, 'temp_min': 37.4, 'temp_max': 37.4, 'pressure': 1015, 'humidity': 44}, 'visibility': 7000, 'wind': {'speed': 6.91, 'deg': 350}, 'clouds': {'all': 100}, 'dt': 1612049205, 'sys': {'type': 1, 'id': 9011, 'country': 'UZ', 'sunrise': 1612059817, 'sunset': 1612096162}, 'timezone': 18000, 'id': 1513491, 'name': 'Yangi Marg`ilon', 'cod': 200}
# oxford
# ...
# tomatlan
# {'coord': {'lon': -105.25, 'lat': 19.9333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 91.63, 'feels_like': 89.92, 'temp_min': 91.63, 'temp_max': 91.63, 'pressure': 1010, 'humidity': 28, 'sea_level': 1010, 'grnd_level': 1005}, 'visibility': 10000, 'wind': {'speed': 5.14, 'deg': 213}, 'clouds': {'all': 0}, 'dt': 1612049246, 'sys': {'country': 'MX', 'sunrise': 1612013811, 'sunset': 1612054303}, 'timezone': -21600, 'id': 3981391, 'name': 'Tomatlán', 'cod': 200}
# tabuk
# {'coord': {'lon': 121.4443, 'lat': 17.4189}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04d'}], 'base': 'stations', 'main': {'temp': 63.75, 'feels_like': 65.35, 'temp_min': 63.75, 'temp_max': 63.75, 'pressure': 1019, 'humidity': 87, 'sea_level': 1019, 'grnd_level': 997}, 'visibility': 10000, 'wind': {'speed': 2.84, 'deg': 330}, 'clouds': {'all': 100}, 'dt': 1612049246, 'sys': {'country': 'PH', 'sunrise': 1612045590, 'sunset': 1612086518}, 'timezone': 28800, 'id': 1684803, 'name': 'Tabuk', 'cod': 200}
# traverse city
# {'coord': {'lon': -85.6206, 'lat': 44.7631}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 28.63, 'feels_like': 16.86, 'temp_min': 28.4, 'temp_max': 28.99, 'pressure': 1022, 'humidity': 46}, 'visibility': 10000, 'wind': {'speed': 10.71, 'deg': 117}, 'clouds': {'all': 90}, 'dt': 1612049034, 'sys': {'type': 1, 'id': 6082, 'country': 'US', 'sunrise': 1612011819, 'sunset': 1612046871}, 'timezone': -18000, 'id': 5012495, 'name': 'Traverse City', 'cod': 200}
# bethanien
# {'coord': {'lon': 17.1583, 'lat': -26.502}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 76.75, 'feels_like': 70.18, 'temp_min': 76.75, 'temp_max': 76.75, 'pressure': 1010, 'humidity': 21, 'sea_level': 1010, 'grnd_level': 902}, 'visibility': 10000, 'wind': {'speed': 5.82, 'deg': 145}, 'clouds': {'all': 0}, 'dt': 1612049246, 'sys': {'country': 'NA', 'sunrise': 1612067100, 'sunset': 1612115071}, 'timezone': 7200, 'id': 3358416, 'name': 'Bethanien', 'cod': 200}
# grand gaube
# {'coord': {'lon': 57.6608, 'lat': -20.0064}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.99, 'feels_like': 82.89, 'temp_min': 75.99, 'temp_max': 75.99, 'pressure': 1013, 'humidity': 87}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 131, 'gust': 5.99}, 'clouds': {'all': 1}, 'dt': 1612049246, 'sys': {'type': 3, 'id': 2002134, 'country': 'MU', 'sunrise': 1612057970, 'sunset': 1612104757}, 'timezone': 14400, 'id': 934479, 'name': 'Grand Gaube', 'cod': 200}
# listvyanskiy
# {'coord': {'lon': 83.4984, 'lat': 54.4399}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': -10.98, 'feels_like': -21.28, 'temp_min': -10.98, 'temp_max': -10.98, 'pressure': 1039, 'humidity': 83, 'sea_level': 1039, 'grnd_level': 1009}, 'visibility': 10000, 'wind': {'speed': 6.29, 'deg': 89}, 'clouds': {'all': 1}, 'dt': 1612049246, 'sys': {'country': 'RU', 'sunrise': 1612059400, 'sunset': 1612090924}, 'timezone': 25200, 'id': 1500468, 'name': 'Listvyanskiy', 'cod': 200}
# kamenka
# {'coord': {'lon': 42.7678, 'lat': 51.3223}, 'weather': [{'id': 500, 'main': 'Rain', 'description': 'light rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 35.01, 'feels_like': 23.7, 'temp_min': 35.01, 'temp_max': 35.01, 'pressure': 1003, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 14.12, 'deg': 175}, 'rain': {'1h': 0.13}, 'clouds': {'all': 100}, 'dt': 1612049246, 'sys': {'type': 3, 'id': 2021293, 'country': 'RU', 'sunrise': 1612068493, 'sunset': 1612101384}, 'timezone': 10800, 'id': 553766, 'name': 'Kamenka', 'cod': 200}
# bafoulabe
# {'coord': {'lon': -10.8321, 'lat': 13.8065}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 79.02, 'feels_like': 70.86, 'temp_min': 79.02, 'temp_max': 79.02, 'pressure': 1011, 'humidity': 14, 'sea_level': 1011, 'grnd_level': 1000}, 'visibility': 10000, 'wind': {'speed': 6.67, 'deg': 42}, 'clouds': {'all': 37}, 'dt': 1612049246, 'sys': {'country': 'ML', 'sunrise': 1611990651, 'sunset': 1612032137}, 'timezone': 0, 'id': 2460755, 'name': 'Bafoulabé', 'cod': 200}
# atar
# {'coord': {'lon': -13.0499, 'lat': 20.5169}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 68.34, 'feels_like': 59.43, 'temp_min': 68.34, 'temp_max': 68.34, 'pressure': 1017, 'humidity': 21, 'sea_level': 1017, 'grnd_level': 991}, 'visibility': 10000, 'wind': {'speed': 8.25, 'deg': 66}, 'clouds': {'all': 59}, 'dt': 1612049247, 'sys': {'country': 'MR', 'sunrise': 1611991737, 'sunset': 1612032115}, 'timezone': 0, 'id': 2381334, 'name': 'Atar', 'cod': 200}
# mount darwin
# {'coord': {'lon': 31.5838, 'lat': -16.7725}, 'weather': [{'id': 501, 'main': 'Rain', 'description': 'moderate rain', 'icon': '10n'}], 'base': 'stations', 'main': {'temp': 67.98, 'feels_like': 71.71, 'temp_min': 67.98, 'temp_max': 67.98, 'pressure': 1010, 'humidity': 97, 'sea_level': 1010, 'grnd_level': 906}, 'visibility': 8226, 'wind': {'speed': 4.45, 'deg': 86}, 'rain': {'1h': 2.64}, 'clouds': {'all': 100}, 'dt': 1612049247, 'sys': {'country': 'ZW', 'sunrise': 1612064507, 'sunset': 1612110738}, 'timezone': 7200, 'id': 885800, 'name': 'Mount Darwin', 'cod': 200}
# cascais
# {'coord': {'lon': -9.4215, 'lat': 38.6979}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 57.52, 'feels_like': 48.43, 'temp_min': 55.99, 'temp_max': 57.99, 'pressure': 1076, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 17.49, 'deg': 307}, 'clouds': {'all': 71}, 'dt': 1612049247, 'sys': {'type': 3, 'id': 2021330, 'country': 'PT', 'sunrise': 1611992711, 'sunset': 1612029400}, 'timezone': 0, 'id': 2269594, 'name': 'Cascais', 'cod': 200}
# houlton
# {'coord': {'lon': -67.8403, 'lat': 46.1262}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 5.36, 'feels_like': -5.62, 'temp_min': 3.99, 'temp_max': 7, 'pressure': 1020, 'humidity': 66}, 'visibility': 10000, 'wind': {'speed': 8.05, 'deg': 360}, 'clouds': {'all': 1}, 'dt': 1612049247, 'sys': {'type': 1, 'id': 4439, 'country': 'US', 'sunrise': 1612007768, 'sunset': 1612042387}, 'timezone': -18000, 'id': 4967563, 'name': 'Houlton', 'cod': 200}
# cayenne
# {'coord': {'lon': -52.3333, 'lat': 4.9333}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 80.6, 'feels_like': 86.36, 'temp_min': 80.6, 'temp_max': 80.6, 'pressure': 1011, 'humidity': 89}, 'visibility': 10000, 'wind': {'speed': 10.36, 'deg': 60}, 'clouds': {'all': 75}, 'dt': 1612049247, 'sys': {'type': 1, 'id': 8669, 'country': 'GF', 'sunrise': 1611999921, 'sunset': 1612042789}, 'timezone': -10800, 'id': 3382160, 'name': 'Cayenne', 'cod': 200}
# bridlington
# {'coord': {'lon': -0.1919, 'lat': 54.0831}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 33.98, 'feels_like': 28.96, 'temp_min': 30.99, 'temp_max': 37, 'pressure': 1007, 'humidity': 84}, 'visibility': 10000, 'wind': {'speed': 1.99, 'deg': 99, 'gust': 4}, 'clouds': {'all': 22}, 'dt': 1612049247, 'sys': {'type': 3, 'id': 2005670, 'country': 'GB', 'sunrise': 1611993080, 'sunset': 1612024600}, 'timezone': 0, 'id': 2654728, 'name': 'Bridlington', 'cod': 200}
# geraldton
# {'coord': {'lon': 114.6, 'lat': -28.7667}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01d'}], 'base': 'stations', 'main': {'temp': 86, 'feels_like': 78.71, 'temp_min': 86, 'temp_max': 86, 'pressure': 1005, 'humidity': 28}, 'visibility': 10000, 'wind': {'speed': 12.66, 'deg': 60}, 'clouds': {'all': 0}, 'dt': 1612049247, 'sys': {'type': 1, 'id': 9522, 'country': 'AU', 'sunrise': 1612043475, 'sunset': 1612091918}, 'timezone': 28800, 'id': 2070998, 'name': 'Geraldton', 'cod': 200}
# kamsack
# {'coord': {'lon': -101.9009, 'lat': 51.5667}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': 17.6, 'feels_like': 8.49, 'temp_min': 17.6, 'temp_max': 17.6, 'pressure': 1017, 'humidity': 100}, 'visibility': 8047, 'wind': {'speed': 6.91, 'deg': 360}, 'snow': {'1h': 0.59}, 'clouds': {'all': 90}, 'dt': 1612049247, 'sys': {'type': 1, 'id': 895, 'country': 'CA', 'sunrise': 1612016915, 'sunset': 1612049590}, 'timezone': -21600, 'id': 5989068, 'name': 'Kamsack', 'cod': 200}
# bartica
# {'coord': {'lon': -58.6167, 'lat': 6.4}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 87.71, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1012, 'humidity': 94}, 'visibility': 10000, 'wind': {'speed': 4.61, 'deg': 30}, 'clouds': {'all': 75}, 'dt': 1612049247, 'sys': {'type': 1, 'id': 8767, 'country': 'GY', 'sunrise': 1612001541, 'sunset': 1612044186}, 'timezone': -14400, 'id': 3379507, 'name': 'Bartica', 'cod': 200}
# raudeberg
# {'coord': {'lon': 5.1352, 'lat': 61.9875}, 'weather': [{'id': 601, 'main': 'Snow', 'description': 'snow', 'icon': '13n'}], 'base': 'stations', 'main': {'temp': 33.01, 'feels_like': 23.34, 'temp_min': 33.01, 'temp_max': 33.01, 'pressure': 1000, 'humidity': 93}, 'visibility': 7622, 'wind': {'speed': 10.63, 'deg': 193}, 'snow': {'1h': 0.6}, 'clouds': {'all': 100}, 'dt': 1612049247, 'sys': {'type': 3, 'id': 2003008, 'country': 'NO', 'sunrise': 1612080447, 'sunset': 1612107495}, 'timezone': 3600, 'id': 3146487, 'name': 'Raudeberg', 'cod': 200}
# yakeshi
# {'coord': {'lon': 120.7333, 'lat': 49.2833}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -20.24, 'feels_like': -29.33, 'temp_min': -20.24, 'temp_max': -20.24, 'pressure': 1026, 'humidity': 86, 'sea_level': 1026, 'grnd_level': 937}, 'visibility': 4273, 'wind': {'speed': 3.85, 'deg': 79}, 'clouds': {'all': 100}, 'dt': 1612049247, 'sys': {'country': 'CN', 'sunrise': 1612049413, 'sunset': 1612083036}, 'timezone': 28800, 'id': 2033536, 'name': 'Yakeshi', 'cod': 200}
# tilichiki
# {'coord': {'lon': 166.1, 'lat': 60.4667}, 'weather': [{'id': 600, 'main': 'Snow', 'description': 'light snow', 'icon': '13d'}], 'base': 'stations', 'main': {'temp': -13.32, 'feels_like': -29.61, 'temp_min': -13.32, 'temp_max': -13.32, 'pressure': 997, 'humidity': 91, 'sea_level': 997, 'grnd_level': 969}, 'visibility': 272, 'wind': {'speed': 16.89, 'deg': 14}, 'snow': {'1h': 0.31}, 'clouds': {'all': 100}, 'dt': 1612049219, 'sys': {'country': 'RU', 'sunrise': 1612041321, 'sunset': 1612069350}, 'timezone': 43200, 'id': 2120591, 'name': 'Tilichiki', 'cod': 200}
# aksarka
# {'coord': {'lon': 67.7975, 'lat': 66.5606}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': -18.47, 'feels_like': -31.56, 'temp_min': -18.47, 'temp_max': -18.47, 'pressure': 1025, 'humidity': 87, 'sea_level': 1025, 'grnd_level': 1022}, 'visibility': 757, 'wind': {'speed': 11.01, 'deg': 150}, 'clouds': {'all': 100}, 'dt': 1612049248, 'sys': {'country': 'RU', 'sunrise': 1612067680, 'sunset': 1612090181}, 'timezone': 18000, 'id': 1512019, 'name': 'Aksarka', 'cod': 200}
# henties bay
# {'coord': {'lon': 14.2845, 'lat': -22.116}, 'weather': [{'id': 802, 'main': 'Clouds', 'description': 'scattered clouds', 'icon': '03n'}], 'base': 'stations', 'main': {'temp': 66.99, 'feels_like': 69.04, 'temp_min': 66.99, 'temp_max': 66.99, 'pressure': 1012, 'humidity': 86}, 'visibility': 10000, 'wind': {'speed': 4, 'deg': 282, 'gust': 7}, 'clouds': {'all': 30}, 'dt': 1612049248, 'sys': {'type': 3, 'id': 2012545, 'country': 'NA', 'sunrise': 1612068199, 'sunset': 1612115351}, 'timezone': 7200, 'id': 3356832, 'name': 'Henties Bay', 'cod': 200}
# halifax
# {'coord': {'lon': -63.5724, 'lat': 44.6453}, 'weather': [{'id': 804, 'main': 'Clouds', 'description': 'overcast clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 18.64, 'feels_like': 11.37, 'temp_min': 18, 'temp_max': 19, 'pressure': 1016, 'humidity': 78}, 'visibility': 10000, 'wind': {'speed': 3, 'deg': 341, 'gust': 5.99}, 'clouds': {'all': 100}, 'dt': 1612049075, 'sys': {'type': 3, 'id': 2019613, 'country': 'CA', 'sunrise': 1612006514, 'sunset': 1612041592}, 'timezone': -14400, 'id': 6324729, 'name': 'Halifax', 'cod': 200}
# trairi
# {'coord': {'lon': -39.2689, 'lat': -3.2778}, 'weather': [{'id': 803, 'main': 'Clouds', 'description': 'broken clouds', 'icon': '04n'}], 'base': 'stations', 'main': {'temp': 79.38, 'feels_like': 83.62, 'temp_min': 79.38, 'temp_max': 79.38, 'pressure': 1011, 'humidity': 80, 'sea_level': 1011, 'grnd_level': 1011}, 'visibility': 10000, 'wind': {'speed': 8.5, 'deg': 92}, 'clouds': {'all': 70}, 'dt': 1612049248, 'sys': {'country': 'BR', 'sunrise': 1611996161, 'sunset': 1612040278}, 'timezone': -10800, 'id': 3386177, 'name': 'Trairi', 'cod': 200}
# apricena
# {'coord': {'lon': 15.4437, 'lat': 41.7839}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 46.4, 'feels_like': 40.46, 'temp_min': 46.4, 'temp_max': 46.4, 'pressure': 1001, 'humidity': 81}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 30}, 'clouds': {'all': 0}, 'dt': 1612049248, 'sys': {'type': 1, 'id': 6678, 'country': 'IT', 'sunrise': 1612073493, 'sunset': 1612109501}, 'timezone': 3600, 'id': 3182958, 'name': 'Apricena', 'cod': 200}
# salta
# {'coord': {'lon': -65.4117, 'lat': -24.7859}, 'weather': [{'id': 761, 'main': 'Dust', 'description': 'dust', 'icon': '50n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 69.75, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1009, 'humidity': 68}, 'visibility': 7000, 'wind': {'speed': 13.8, 'deg': 70}, 'clouds': {'all': 40}, 'dt': 1612049248, 'sys': {'type': 1, 'id': 8267, 'country': 'AR', 'sunrise': 1612000646, 'sunset': 1612048343}, 'timezone': -10800, 'id': 3838233, 'name': 'Salta', 'cod': 200}
# trang
# {'coord': {'lon': 99.5, 'lat': 7.5}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 73.4, 'feels_like': 80.91, 'temp_min': 73.4, 'temp_max': 73.4, 'pressure': 1011, 'humidity': 100}, 'visibility': 6000, 'wind': {'speed': 3.44, 'deg': 60}, 'clouds': {'all': 20}, 'dt': 1612049248, 'sys': {'type': 1, 'id': 9284, 'country': 'TH', 'sunrise': 1612050078, 'sunset': 1612092564}, 'timezone': 25200, 'id': 1150006, 'name': 'Trang', 'cod': 200}
# igboho
# {'coord': {'lon': 3.75, 'lat': 8.8333}, 'weather': [{'id': 800, 'main': 'Clear', 'description': 'clear sky', 'icon': '01n'}], 'base': 'stations', 'main': {'temp': 75.34, 'feels_like': 70.41, 'temp_min': 75.34, 'temp_max': 75.34, 'pressure': 1010, 'humidity': 19, 'sea_level': 1010, 'grnd_level': 964}, 'visibility': 10000, 'wind': {'speed': 1.97, 'deg': 41}, 'clouds': {'all': 0}, 'dt': 1612049248, 'sys': {'country': 'NG', 'sunrise': 1612073159, 'sunset': 1612115448}, 'timezone': 3600, 'id': 2338711, 'name': 'Igboho', 'cod': 200}
# pitimbu
# {'coord': {'lon': -34.8086, 'lat': -7.4706}, 'weather': [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02n'}], 'base': 'stations', 'main': {'temp': 78.8, 'feels_like': 84.24, 'temp_min': 78.8, 'temp_max': 78.8, 'pressure': 1014, 'humidity': 83}, 'visibility': 10000, 'wind': {'speed': 6.91, 'deg': 120}, 'clouds': {'all': 20}, 'dt': 1612049248, 'sys': {'type': 1, 'id': 8391, 'country': 'BR', 'sunrise': 1611994767, 'sunset': 1612039531}, 'timezone': -10800, 'id': 3391889, 'name': 'Pitimbu', 'cod': 200}

# %%
weather_dict = {
    "City" : city2,
    "Lat" : lat,
    "Long" : long,
    "Max Temp": max_temp,
    "Humidity" : humidity,
    "Cloudiness": cloudiness,
    "Wind Speed" : wind_speed,
    "Country" : country,
    "Date" : date
}
weather_data = pd.DataFrame.from_dict(weather_dict, orient = 'index').transpose()
weather_data
# Out:
#                  City      Lat     Long Max Temp Humidity Cloudiness  \
# 0               bluff    -46.6  168.333    57.16       67        100
# 1    marechal deodoro  -9.7103  -35.895       77       94         40
# 2            bengkulu  -3.8004  102.266    75.24       93         98
# 3             ushuaia    -54.8    -68.3     51.8       62         20
# 4           jamestown   42.097 -79.2353       19       73          1
# ..                ...      ...      ...      ...      ...        ...
# 532          apricena  41.7839  15.4437     46.4       81          0
# 533             salta -24.7859 -65.4117     73.4       68         40
# 534             trang      7.5     99.5     73.4      100         20
# 535            igboho   8.8333     3.75    75.34       19          0
# 536           pitimbu  -7.4706 -34.8086     78.8       83         20
#
#     Wind Speed Country        Date
# 0         0.98      NZ  1612049195
# 1         4.61      BR  1612049196
# 2        10.16      ID  1612049196
# 3        24.16      AR  1612049196
# 4         2.01      US  1612049016
# ..         ...     ...         ...
# 532       6.91      IT  1612049248
# 533       13.8      AR  1612049248
# 534       3.44      TH  1612049248
# 535       1.97      NG  1612049248
# 536       6.91      BR  1612049248
#
# [537 rows x 9 columns]

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_data.to_csv ("../output_data/weather_data_file.csv",encoding="utf-8", index=False)
weather_data
# Out:
#                  City      Lat     Long Max Temp Humidity Cloudiness  \
# 0               bluff    -46.6  168.333    57.16       67        100
# 1    marechal deodoro  -9.7103  -35.895       77       94         40
# 2            bengkulu  -3.8004  102.266    75.24       93         98
# 3             ushuaia    -54.8    -68.3     51.8       62         20
# 4           jamestown   42.097 -79.2353       19       73          1
# ..                ...      ...      ...      ...      ...        ...
# 532          apricena  41.7839  15.4437     46.4       81          0
# 533             salta -24.7859 -65.4117     73.4       68         40
# 534             trang      7.5     99.5     73.4      100         20
# 535            igboho   8.8333     3.75    75.34       19          0
# 536           pitimbu  -7.4706 -34.8086     78.8       83         20
#
#     Wind Speed Country        Date
# 0         0.98      NZ  1612049195
# 1         4.61      BR  1612049196
# 2        10.16      ID  1612049196
# 3        24.16      AR  1612049196
# 4         2.01      US  1612049016
# ..         ...     ...         ...
# 532       6.91      IT  1612049248
# 533       13.8      AR  1612049248
# 534       3.44      TH  1612049248
# 535       1.97      NG  1612049248
# 536       6.91      BR  1612049248
#
# [537 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
#  Get the indices of cities that have humidity over 100%.
humid_check = weather_data['Humidity'].max()
humid_check
# Out:
# 100

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %%
#Skipping this step since no location with humidity above 100

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Max Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Max Temperature")
plt.ylabel("Max Temperature (Farenheit)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/citylatitudevsmaxtemp.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/latitudevshumidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/latitudevscloudiness.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build a scatter plot for each data type
plt.scatter(weather_data["Lat"], weather_data["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs Wind Speed")
plt.ylabel("Wind Speed(MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("../output_data/latitudevswindspeed.png")

# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat > 0]['Lat']
y_values = weather_data[weather_data.Lat > 0]['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+  "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,-40),fontsize=15,color="red")
plt.savefig("../output_data/northmaxtemplinearreg.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat < 0]['Lat']
y_values = weather_data[weather_data.Lat < 0]['Max Temp']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+ "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Temperature')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,90),fontsize=15,color="red")
plt.savefig("../output_data/southmaxtemplinearreg.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat > 0]['Lat']
y_values = weather_data[weather_data.Lat > 0]['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+  "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,20),fontsize=15,color="red")
plt.savefig("../output_data/northhumiditylinearreg.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat < 0]['Lat']
y_values = weather_data[weather_data.Lat < 0]['Humidity']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+ "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Humidity')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,20),fontsize=15,color="red")
plt.savefig("../output_data/southhumiditytemplinearreg.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat > 0]['Lat']
y_values = weather_data[weather_data.Lat > 0]['Cloudiness']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+  "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.savefig("../output_data/northcloudinesslinearreg.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat < 0]['Lat']
y_values = weather_data[weather_data.Lat < 0]['Cloudiness']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+ "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Cloudiness')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,10),fontsize=15,color="red")
plt.savefig("../output_data/southcloudinesstemplinearreg.png")
plt.show()

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat > 0]['Lat']
y_values = weather_data[weather_data.Lat > 0]['Wind Speed']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+  "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(20,30),fontsize=15,color="red")
plt.savefig("../output_data/northwindspeedlinearreg.png")
plt.show()

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Create a Scatter Plot for temperature vs latitude
x_values = weather_data[weather_data.Lat < 0]['Lat']
y_values = weather_data[weather_data.Lat < 0]['Wind Speed']

# Perform a linear regression on temperature vs. latitude
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values.astype(float), y_values.astype(float))

# Get regression values
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x +" + str(round(intercept,2))+ "  r-value "+ str(round(rvalue,2))


plt.scatter(x_values,y_values)
plt.xlabel('Latitude')
plt.ylabel('Wind Speed')
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(-50,25),fontsize=15,color="red")
plt.savefig("../output_data/southwindspeedtemplinearreg.png")
plt.show()
